# %%
#Voice Activity Detection

import contextlib
import numpy as np
import wave
import librosa
import webrtcvad


def read_wave(path):
    with contextlib.closing(wave.open(path, 'rb')) as wf:
        num_channels = wf.getnchannels()
        assert num_channels == 1
        sample_width = wf.getsampwidth()
        assert sample_width == 2
        sample_rate = wf.getframerate()
        assert sample_rate in (8000, 16000, 32000, 48000)
        pcm_data = wf.readframes(wf.getnframes())
        return pcm_data, sample_rate


class Frame(object):
  def __init__(self, bytes, timestamp, duration):
        self.bytes = bytes
        self.timestamp = timestamp
        self.duration = duration


def frame_generator(frame_duration_ms, audio, sample_rate):
    n = int(sample_rate * (frame_duration_ms / 1000.0) * 2)
    offset = 0
    timestamp = 0.0
    duration = (float(n) / sample_rate) / 2.0
    while offset + n < len(audio):
        yield Frame(audio[offset:offset + n], timestamp, duration)
        timestamp += duration
        offset += n


def vad_collector(vad, frames, sample_rate):
    is_speech = []
    for frame in frames:
        is_speech.append(vad.is_speech(frame.bytes, sample_rate))
    return is_speech


def vad(file):
    audio, sample_rate = read_wave(file)
    vad = webrtcvad.Vad(2)
    frames = frame_generator(10, audio, sample_rate)
    frames = list(frames)
    segments = vad_collector(vad, frames, sample_rate)
    return segments

def speech(file):
  dummy = 0
  data = []
  segments = vad(file)
  audio, sr = librosa.load(file)
  for i in segments:
    if i == True:
      data.append(audio[dummy:dummy + 480])
      dummy = dummy + 480
    else:
      dummy = dummy + 480
  data = np.ravel(np.asarray(data))

  return data

def fxn(file):
  segments = vad(file)
  segments = np.asarray(segments)
  dummy = 0.01*np.where(segments[:-1] != segments[1:])[0] +.01 
  if len(dummy)%2==0:
    dummy = dummy
  else:
    dummy = np.delete(dummy, len(dummy)-1)

  voice = dummy.reshape(int(len(dummy)/2),2)
  
  return voice

# %%
input_shape=(137,35)

# %%
#Segmentation (Each Segment will have only one Speaker)
#%tensorflow_version 1.x
import librosa
import matplotlib.pyplot as plt
from keras import layers
from keras.layers.core import Dense
from keras.models import Sequential
from keras.layers import Bidirectional, TimeDistributed, Dropout
from keras.layers import LSTM
import numpy as np
import keras
# Out:
# 2022-12-20 14:13:10.939590: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    #x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.TimeDistributed(Dense(dim, activation="relu"))(x)
        x = layers.Dropout(mlp_dropout)(x)
    
    #outputs = layers.Dense(137)(x)
    outputs = layers.TimeDistributed(Dense(1, activation="softmax"))(x)
    return keras.Model(inputs, outputs)

# %%
model = build_model(
    input_shape,
    head_size=2,
    num_heads=2,
    ff_dim=4,
    num_transformer_blocks=1,
    mlp_units=[12],
    mlp_dropout=0.4,
    dropout=0.25,
)
# Out:
# 2022-12-20 14:14:13.970670: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-20 14:14:13.991017: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
#Upload the pre-trained model file from Google Drive. Change the Path accordingly.
h5_model_file ='SPD/model/trans_2014.h5'
model.load_weights(h5_model_file)

# %%
import tensorflow

# %%
from tensorflow import keras
from keras.layers import Dense
from keras.utils.vis_utils import plot_model

# %%
def multi_segmentation(file):
    frame_size = 2048
    frame_shift = 512
    y, sr = librosa.load(file)
    mfccs = librosa.feature.mfcc(y, sr, n_mfcc=12, hop_length=frame_shift, n_fft=frame_size)
    mfcc_delta = librosa.feature.delta(mfccs)
    mfcc_delta2 = librosa.feature.delta(mfccs, order=2)

    mfcc = mfccs[1:, ]
    norm_mfcc = (mfcc - np.mean(mfcc, axis=1, keepdims=True)) / np.std(mfcc, axis=1, keepdims=True)
    norm_mfcc_delta = (mfcc_delta - np.mean(mfcc_delta, axis=1, keepdims=True)) / np.std(mfcc_delta, axis=1, keepdims=True)
    norm_mfcc_delta2 = (mfcc_delta2 - np.mean(mfcc_delta2, axis=1, keepdims=True)) / np.std(mfcc_delta2, axis=1, keepdims=True)

    ac_feature = np.vstack((norm_mfcc, norm_mfcc_delta, norm_mfcc_delta2))
    print(ac_feature.shape)

    sub_seq_len = int(3.2 * sr / frame_shift)
    sub_seq_step = int(0.8 * sr / frame_shift)

    def extract_feature():
        feature_len = ac_feature.shape[1]
        sub_train_x = []
        for i in range(0, feature_len-sub_seq_len, sub_seq_step):
            sub_seq_x = np.transpose(ac_feature[:, i: i+sub_seq_len])
            sub_train_x.append(sub_seq_x[np.newaxis, :, :])
        return np.vstack(sub_train_x), feature_len

    predict_x, feature_len = extract_feature()
    print(predict_x.shape)

    predict_y = model.predict(predict_x)
    print(predict_y.shape)

    score_acc = np.zeros((feature_len, 1))
    score_cnt = np.ones((feature_len, 1))

    for i in range(predict_y.shape[0]):
        for j in range(predict_y.shape[1]):
            index = i*sub_seq_step+j
            score_acc[index] += predict_y[i, j, 0]
            score_cnt[index] += 1

    score_norm = score_acc / score_cnt

    wStart = 0
    wEnd = 200
    wGrow = 200
    delta = 25

    store_cp = []
    index = 0
    while wEnd < feature_len:
        score_seg = score_norm[wStart:wEnd]
        max_v = np.max(score_seg)
        max_index = np.argmax(score_seg)
        index = index + 1
        if max_v > 0.5:
            temp = wStart + max_index
            store_cp.append(temp)
            wStart = wStart + max_index + 50
            wEnd = wStart + wGrow
        else:
            wEnd = wEnd + wGrow

    seg_point = np.array(store_cp)*frame_shift

    plt.figure('speech segmentation plot')
    plt.plot(np.arange(0, len(y)) / (float)(sr), y, "b-")

    for i in range(len(seg_point)):
        plt.vlines(seg_point[i] / (float)(sr), -1, 1, colors="c", linestyles="dashed")
        plt.vlines(seg_point[i] / (float)(sr), -1, 1, colors="r", linestyles="dashed")
    plt.xlabel("Time/s")
    plt.ylabel("Speech Amp")
    plt.grid(True)
    plt.show()

    return np.asarray(seg_point) / float(sr)

# %%
#Re-segmentation (Based on Combining VAD and Segementation Output)
def group_intervals(a):
    a = a.tolist()
    ans = []

    curr = None
    for x in a:
        # no previous interval under consideration
        if curr == None:
          curr = x
        else:
            # check if we can merge the intervals
            if x[0]-curr[1] < 1:
                curr[1] = x[1]
            else:
            # if we cannot merge, push the current element to ans
                ans.append(curr)
                curr = x

        if curr is not None:
            ans.append(curr)

    d1 = np.asarray(ans)
    d2 = np.unique(d1)
    d3 = d2.reshape(int(len(d2)/2),2)
    return d3
    
def spliting(seg,arr):
  arr1 = arr.tolist()
  temp = arr.copy()
  
  for i in range(len(seg)-1):
    temp1 = float(seg[i])
    # print(temp1)
    #for j in range(len(arr)-1):
    for j in range(len(arr)):
      if ((temp1 > arr[j][0]) & (temp1 < arr[j][1])):
        arr1[j].insert(-1,(temp1))

  #for i in range(len(arr1-1)):
  for i in range(len(arr1)):
    size=len(arr1[i])
    if size>=3:
      arr1[i].pop(-2) if arr1[i][-1]-arr1[i][-2]<0.2 else True
      
  return arr1
  
def final_reseg(arr):
  z=[]
  for i in arr:
    if len(i)==2:
      z.append(i)
    else:
      temp = len(i)
      for j in range(temp-1):
        if j!=temp-1:
          temp1 = [i[j],i[j+1]-0.01]
          z.append(temp1)
        elif j==temp-1:
          temp1 = [i[j],i[j+1]]
          z.append(temp1)
  
  return np.asarray(z)

# %%
#Embedding Extraction
import torch
import librosa
from pyannote.core import Segment

def embeddings_(audio_path,resegmented,range):
  model_emb = torch.hub.load('pyannote/pyannote-audio', 'emb')
  
  embedding = model_emb({'audio': audio_path})
  for window, emb in embedding:
    assert isinstance(window, Segment)
    assert isinstance(emb, np.ndarray)

  y, sr = librosa.load(audio_path)
  myDict={}
  myDict['audio'] = audio_path
  myDict['duration'] = len(y)/sr

  data=[]
  for i in resegmented:
    excerpt = Segment(start=i[0], end=i[0]+range)
    emb = model_emb.crop(myDict,excerpt)
    data.append(emb.T)
  data= np.asarray(data)
  
  return data.reshape(len(data),512)

# %%
#Clustering (Mean-Shift)
from sklearn.manifold import TSNE
from sklearn.cluster import MeanShift
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
scaler = StandardScaler()
def clustering(emb):
  temp = scaler.fit_transform(emb)
  Y = TSNE(n_components=2).fit_transform(temp)
  cluster_ms = MeanShift(bandwidth = 3,max_iter='200',cluster_all=False).fit(Y)
  y_ms = cluster_ms.predict(Y)
  clus_centre = cluster_ms.cluster_centers_
  n_speakers = clus_centre.shape[0]
  plt.figure
  plt.scatter(Y[:,0], Y[:, 1], c=y_ms, s=50, cmap='viridis')
  plt.show()

  return y_ms, n_speakers

# %%
#Generating Hypothesis
from pyannote.core import Annotation, Segment
def hypothesis_gen(hyp_df):
  hyp_records = hyp_df.to_records(index=False)
  hyp_rec = list(hyp_records)
  hypothesis = Annotation()
  for i in range(len(hyp_rec)-1):
    hypothesis[Segment(hyp_rec[i][1], hyp_rec[i][2])] = hyp_rec[i][0]

  return hypothesis

# %%
#Diarization 
from sklearn import preprocessing
import pandas as pd
def diarization(audiofile):
    voice = fxn(audiofile)
    segmented = multi_segmentation(audiofile)
    gp = group_intervals(voice)
    splt = spliting(segmented,gp)
    resegmented = final_reseg(splt)
    embeddings = embeddings_(audiofile,resegmented,2)
    speak_id , n_speakers = clustering(embeddings)
    label_list = []
    alpha = 'A'
    for i in range(0, n_speakers): 
        label_list.append(alpha) 
        alpha = chr(ord(alpha) + 1) 
    lb = preprocessing.LabelEncoder()
    label_hyp = lb.fit(label_list)
    speaker_id = lb.inverse_transform(speak_id)
    hyp_df = pd.DataFrame({'Speaker_id': speaker_id,'Offset': resegmented[:, 0], 'end': resegmented[:, 1]})
    result_hypo = hypothesis_gen(hyp_df)  
    return segmented, n_speakers, hyp_df, result_hypo

# %%
import pyannote.audio.features

# %%
pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyannote.audio
# Out:
# Requirement already satisfied: pyannote.audio in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (1.1.2)
# Requirement already satisfied: pyannote.metrics>=2.3 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (3.0.1)
# Requirement already satisfied: tqdm>=4.29.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (4.64.1)
# Requirement already satisfied: pyannote.pipeline<2.0.0,>=1.5.2 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (1.5.2)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (2.4.0)
# Requirement already satisfied: soundfile>=0.10.2 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (0.11.0)
# Requirement already satisfied: Pillow>=6.2.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (9.2.0)
# Requirement already satisfied: cachetools>=2.0.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (4.2.2)
# Requirement already satisfied: tensorboard>=2.0.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (2.10.0)
# Requirement already satisfied: pandas>=0.18.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (1.5.1)
# Requirement already satisfied: pyannote.database>=4.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (4.1.3)
# Requirement already satisfied: pescador>=2.1.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (2.1.0)
# Requirement already satisfied: scikit-learn>=0.20.2 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (1.1.3)
# Requirement already satisfied: sortedcollections>=1.0.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (2.1.0)
# Requirement already satisfied: librosa>=0.8.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (0.9.2)
# Requirement already satisfied: pyYAML>=3.12 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (6.0)
# Requirement already satisfied: pyannote.core>=4.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.audio) (4.2)
# Requirement already satisfied: numpy>=1.17.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from librosa>=0.8.0->pyannote.audio) (1.23.5)
# Requirement already satisfied: resampy>=0.2.2 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from librosa>=0.8.0->pyannote.audio) (0.4.2)
# Requirement already satisfied: audioread>=2.1.9 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from librosa>=0.8.0->pyannote.audio) (3.0.0)
# Requirement already satisfied: pooch>=1.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from librosa>=0.8.0->pyannote.audio) (1.4.0)
# Requirement already satisfied: decorator>=4.0.10 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from librosa>=0.8.0->pyannote.audio) (5.1.1)
# Requirement already satisfied: packaging>=20.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from librosa>=0.8.0->pyannote.audio) (21.3)
# Requirement already satisfied: scipy>=1.2.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from librosa>=0.8.0->pyannote.audio) (1.8.1)
# Requirement already satisfied: joblib>=0.14 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from librosa>=0.8.0->pyannote.audio) (1.1.1)
# Requirement already satisfied: numba>=0.45.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from librosa>=0.8.0->pyannote.audio) (0.56.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pandas>=0.18.0->pyannote.audio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pandas>=0.18.0->pyannote.audio) (2022.1)
# Requirement already satisfied: pyzmq>=15.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pescador>=2.1.0->pyannote.audio) (23.2.0)
# Requirement already satisfied: six>=1.8 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pescador>=2.1.0->pyannote.audio) (1.16.0)
# Requirement already satisfied: simplejson>=3.8.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.core>=4.1->pyannote.audio) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.core>=4.1->pyannote.audio) (4.4.0)
# Requirement already satisfied: typer[all]>=0.2.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.database>=4.0->pyannote.audio) (0.7.0)
# Requirement already satisfied: tabulate>=0.7.7 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.metrics>=2.3->pyannote.audio) (0.9.0)
# Requirement already satisfied: docopt>=0.6.2 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.metrics>=2.3->pyannote.audio) (0.6.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.metrics>=2.3->pyannote.audio) (3.5.3)
# Requirement already satisfied: sympy>=1.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.metrics>=2.3->pyannote.audio) (1.11.1)
# Requirement already satisfied: optuna>=1.4 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (3.0.4)
# Requirement already satisfied: filelock>=3.0.10 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (3.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from scikit-learn>=0.20.2->pyannote.audio) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from soundfile>=0.10.2->pyannote.audio) (1.15.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard>=2.0.0->pyannote.audio) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard>=2.0.0->pyannote.audio) (3.3.4)
# Requirement already satisfied: wheel>=0.26 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard>=2.0.0->pyannote.audio) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard>=2.0.0->pyannote.audio) (1.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard>=2.0.0->pyannote.audio) (2.6.0)
# Requirement already satisfied: absl-py>=0.4 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard>=2.0.0->pyannote.audio) (1.3.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard>=2.0.0->pyannote.audio) (0.4.4)
# Requirement already satisfied: setuptools>=41.0.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard>=2.0.0->pyannote.audio) (65.5.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard>=2.0.0->pyannote.audio) (0.6.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard>=2.0.0->pyannote.audio) (1.8.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard>=2.0.0->pyannote.audio) (3.19.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard>=2.0.0->pyannote.audio) (2.28.1)
# Requirement already satisfied: pycparser in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->pyannote.audio) (2.21)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.0.0->pyannote.audio) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.0.0->pyannote.audio) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.0.0->pyannote.audio) (1.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=2.3->pyannote.audio) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=2.3->pyannote.audio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=2.3->pyannote.audio) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=2.3->pyannote.audio) (1.4.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from numba>=0.45.1->librosa>=0.8.0->pyannote.audio) (0.39.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (1.4.44)
# Requirement already satisfied: cliff in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (4.1.0)
# Requirement already satisfied: alembic>=1.5.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (1.8.1)
# Requirement already satisfied: cmaes>=0.8.2 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (0.9.0)
# Requirement already satisfied: importlib-metadata<5.0.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (4.11.3)
# Requirement already satisfied: colorlog in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (6.7.0)
# Requirement already satisfied: appdirs in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pooch>=1.0->librosa>=0.8.0->pyannote.audio) (1.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard>=2.0.0->pyannote.audio) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard>=2.0.0->pyannote.audio) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard>=2.0.0->pyannote.audio) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard>=2.0.0->pyannote.audio) (2022.9.24)
# Requirement already satisfied: mpmath>=0.19 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from sympy>=1.1->pyannote.metrics>=2.3->pyannote.audio) (1.2.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from typer[all]>=0.2.1->pyannote.database>=4.0->pyannote.audio) (8.0.4)
# Requirement already satisfied: rich<13.0.0,>=10.11.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from typer[all]>=0.2.1->pyannote.database>=4.0->pyannote.audio) (12.6.0)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from typer[all]>=0.2.1->pyannote.database>=4.0->pyannote.audio) (1.5.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from typer[all]>=0.2.1->pyannote.database>=4.0->pyannote.audio) (0.4.6)
# Requirement already satisfied: Mako in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from alembic>=1.5.0->optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (1.2.4)
# Requirement already satisfied: zipp>=0.5 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from importlib-metadata<5.0.0->optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.0.0->pyannote.audio) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.0.0->pyannote.audio) (3.2.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from rich<13.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database>=4.0->pyannote.audio) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from rich<13.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database>=4.0->pyannote.audio) (2.11.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from sqlalchemy>=1.3.0->optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (2.0.1)
# Requirement already satisfied: autopage>=0.4.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from cliff->optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (0.5.1)
# Requirement already satisfied: stevedore>=2.0.1 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from cliff->optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (4.1.1)
# Requirement already satisfied: PrettyTable>=0.7.2 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from cliff->optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (3.5.0)
# Requirement already satisfied: cmd2>=1.0.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from cliff->optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (2.4.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from cmd2>=1.0.0->cliff->optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (0.2.5)
# Requirement already satisfied: pyperclip>=1.6 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from cmd2>=1.0.0->cliff->optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (1.8.2)
# Requirement already satisfied: attrs>=16.3.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from cmd2>=1.0.0->cliff->optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (22.1.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from stevedore>=2.0.1->cliff->optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (5.11.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages (from Mako->alembic>=1.5.0->optuna>=1.4->pyannote.pipeline<2.0.0,>=1.5.2->pyannote.audio) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Code execution starts from here.Give the path of audio file for Speaker Diarization (It should be Mono type.)
segmented, n_clusters, hyp_df, result_hypo = diarization('SRU/ES2003a.wav')
print(n_clusters)
print(hyp_df)
result_hypo
# Out:
# /tmp/ipykernel_13536/1072253976.py:5: FutureWarning: Pass y=[-0.00551227 -0.00907357 -0.00909966 ...  0.00080274  0.00052149
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfccs = librosa.feature.mfcc(y, sr, n_mfcc=12, hop_length=frame_shift, n_fft=frame_size)
# (35, 49086)
# (1440, 137, 35)
# 45/45 [==============================] - 2s 43ms/step
# (1440, 137, 1)
# Using cache found in /home/cruz/.cache/torch/hub/pyannote_pyannote-audio_main
# Downloading list of pretrained models and pipelines to "/home/cruz/.pyannote/hub/pretrained.yml".
#   0%|          | 0.00/901 [00:00<?, ?B/s]
# Downloading pretrained model "emb_voxceleb" to "/home/cruz/.pyannote/hub/models/emb_voxceleb.zip".
#   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/pyannote/audio/embedding/approaches/arcface_loss.py:170: FutureWarning: The 's' parameter is deprecated in favor of 'scale', and will be removed in a future release
#   warnings.warn(msg, FutureWarning)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# 69
#     Speaker_id       Offset          end
# 0            {     2.190000     3.147914
# 1            h     3.157914     4.726871
# 2            c     4.736871     6.305828
# 3            v     6.315828     7.884785
# 4            u     7.894785     9.463741
# ..         ...          ...          ...
# 618          W  1128.470000  1128.944195
# 619          W  1128.954195  1130.523152
# 620          U  1130.533152  1132.102109
# 621          d  1132.112109  1133.681066
# 622          Q  1133.691066  1139.060000
#
# [623 rows x 3 columns]
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 130 (\x82) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 131 (\x83) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 132 (\x84) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 133 (\x85) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#Evaluation (DER)
def reference_gen(annotation_path):
  df = pd.read_csv(annotation_path)
  ref_df = df[df['filename'] == 'ES2003a']
  ref_df = ref_df.assign(end = ref_df.Offset + ref_df.Duration)
  ref_df = ref_df[['Speaker_id','Offset','end']]
  ref_records = ref_df.to_records(index=False)
  ref_rec = list(ref_records)
  reference = Annotation()
  for i in range(len(ref_rec)-1):
    reference[Segment(ref_rec[i][1], ref_rec[i][2])] = ref_rec[i][0]

  return reference, ref_df

# %%
#Give the path for Annotations File of Audio for calculating DER.
reference, ref_df = reference_gen('SRU/ES2003a.csv')
#Visualization (Comparing Between Ground Truth and Hypothesis)
reference

# %%
result_hypo
# Out:
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 130 (\x82) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 131 (\x83) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 132 (\x84) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 133 (\x85) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from pyannote.metrics.diarization import DiarizationErrorRate
from pyannote.metrics.diarization import DiarizationPurity
from pyannote.metrics.diarization import DiarizationCoverage
#Upload the annotation file from Google Drive. Change the Path accordingly.
result_ref, ref_df = reference_gen('SRU/ES2003a.csv')
diarizationErrorRate = DiarizationErrorRate()
print("DER = {0:.3f}".format(diarizationErrorRate(result_ref, result_hypo)))
#To Evaluate particular Segment of audio-file.
diarizationErrorRate(result_ref, result_hypo, detailed=True, uem=Segment(0, 40))
#Purity 
purity = DiarizationPurity()
print("Purity = {0:.3f}".format(purity(result_ref, result_hypo, uem=Segment(0, 40))))
#Coverage
coverage = DiarizationCoverage()
print("Coverage = {0:.3f}".format(coverage(result_ref, result_hypo, uem=Segment(0, 40))))
# Out:
# /home/cruz/miniconda3/envs/myenv/lib/python3.9/site-packages/pyannote/metrics/utils.py:183: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# DER = 1.031
# Purity = 0.868
# Coverage = 0.281
